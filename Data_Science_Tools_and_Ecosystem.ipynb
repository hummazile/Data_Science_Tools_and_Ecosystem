# %% [markdown]
# # My Data Science Final Project

# %% [markdown]
# ## Introduction
# This notebook demonstrates basic data science concepts including arithmetic operations, data science tools, libraries, and more.

# %% [markdown]
# ### Data Science Languages
# Common languages used in data science include:
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia

# %% [markdown]
# ### Data Science Libraries
# Some popular libraries are:
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn

# %% [markdown]
# ### Data Science Tools
#
# | Tool          | Purpose                  |
# |---------------|-------------------------|
# | Jupyter       | Notebook environment     |
# | RStudio       | Statistical analysis     |
# | GitHub        | Version control          |
# | Tableau       | Data visualization       |
# | VS Code       | Code editor              |

# %% [markdown]
# ### Arithmetic Expression Examples
# Below are some examples of arithmetic operations in Python.

# %%
# Multiply and add numbers
a = 5
b = 10
c = 2
result = a * b + c
result
# Out:
# 52

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
hours
# Out:
# 2.5

# %% [markdown]
# ### Objectives
# - Learn basic Python operations
# - Understand common data science tools
# - Explore data science libraries
# - Practice Markdown formatting

# %% [markdown]
# ### Author
# Zile Humma
